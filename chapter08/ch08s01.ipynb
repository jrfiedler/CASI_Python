# %% [markdown]
# # 8.1 Logistic Regression

# %% [markdown]
# ### Setup

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm

# %% [markdown]
# ### Spam data

# %%
spam = pd.read_csv("../data/SPAM.csv")

# %%
spam.head()
# Out:
#    spam  testid  make  address   all   3d   our  over  remove  internet  \
# 0  True    True  0.00     0.64  0.64  0.0  0.32  0.00    0.00      0.00
# 1  True   False  0.21     0.28  0.50  0.0  0.14  0.28    0.21      0.07
# 2  True    True  0.06     0.00  0.71  0.0  1.23  0.19    0.19      0.12
# 3  True   False  0.00     0.00  0.00  0.0  0.63  0.00    0.31      0.63
# 4  True   False  0.00     0.00  0.00  0.0  0.63  0.00    0.31      0.63
#
#     ...     conference   ch;    ch(  ch[    ch!    ch$    ch#  crl.ave  \
# 0   ...            0.0  0.00  0.000  0.0  0.778  0.000  0.000    3.756
# 1   ...            0.0  0.00  0.132  0.0  0.372  0.180  0.048    5.114
# 2   ...            0.0  0.01  0.143  0.0  0.276  0.184  0.010    9.821
# 3   ...            0.0  0.00  0.137  0.0  0.137  0.000  0.000    3.537
# 4   ...            0.0  0.00  0.135  0.0  0.135  0.000  0.000    3.537
#
#    crl.long  crl.tot
# 0        61      278
# 1       101     1028
# 2       485     2259
# ...

# %% [markdown]
# ### Fit the logistic model

# %%
spam["spam"] = spam.spam.astype("int")

# %%
X = spam.drop(["spam", "testid"], axis=1)
# Standardize the inputs
X = (X - X.mean()) / np.sqrt(X.var(ddof=1))
X = sm.add_constant(X)

# %%
spam_model = sm.Logit(spam.spam, X)
spam_res = spam_model.fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.197323
#          Iterations 15

# %% [markdown]
# ### Table 8.3

# %%
spam_res.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                   spam   No. Observations:                 4601
# Model:                          Logit   Df Residuals:                     4543
# Method:                           MLE   Df Model:                           57
# Date:                Wed, 27 Mar 2019   Pseudo R-squ.:                  0.7057
# Time:                        16:09:56   Log-Likelihood:                -907.88
# converged:                       True   LL-Null:                       -3085.1
#                                         LLR p-value:                     0.000
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -12.2653      1.991     -6.161      0.000     -16.167      -8.363
# make          -0.1189      0.071     -1.683      0.092      -0.257       0.020
# ...
