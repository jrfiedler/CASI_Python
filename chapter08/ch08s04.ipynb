# %% [markdown]
# # 8.4 Regression Trees

# %% [markdown]
# ### Setup

# %%
import pandas as pd
from sklearn import tree
import graphviz

# %%
spam = pd.read_csv("../data/SPAM.csv")

# %%
spam.head()
# Out:
#    spam  testid  make  address   all   3d   our  over  remove  internet  \
# 0  True    True  0.00     0.64  0.64  0.0  0.32  0.00    0.00      0.00
# 1  True   False  0.21     0.28  0.50  0.0  0.14  0.28    0.21      0.07
# 2  True    True  0.06     0.00  0.71  0.0  1.23  0.19    0.19      0.12
# 3  True   False  0.00     0.00  0.00  0.0  0.63  0.00    0.31      0.63
# 4  True   False  0.00     0.00  0.00  0.0  0.63  0.00    0.31      0.63
#
#     ...     conference   ch;    ch(  ch[    ch!    ch$    ch#  crl.ave  \
# 0   ...            0.0  0.00  0.000  0.0  0.778  0.000  0.000    3.756
# 1   ...            0.0  0.00  0.132  0.0  0.372  0.180  0.048    5.114
# 2   ...            0.0  0.01  0.143  0.0  0.276  0.184  0.010    9.821
# 3   ...            0.0  0.00  0.137  0.0  0.137  0.000  0.000    3.537
# 4   ...            0.0  0.00  0.135  0.0  0.135  0.000  0.000    3.537
#
#    crl.long  crl.tot
# 0        61      278
# 1       101     1028
# 2       485     2259
# ...

# %% [markdown]
# ### Fit decision tree

# %%
X = spam.drop(["spam", "testid"], axis=1)
y = spam.spam

# %%
model = tree.DecisionTreeClassifier(criterion="gini", max_leaf_nodes=7)
model.fit(X, y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=7, min_impurity_decrease=0.0,
#             min_impurity_split=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             presort=False, random_state=None, splitter='best')

# %% [markdown]
# ### Figure 8.7

# %%
dot_data = tree.export_graphviz(model, feature_names=X.columns)  
graph = graphviz.Source(dot_data)  
graph

# %% [markdown]
# This is close to the book's example, which is hard to reproduce without knowing the parameter settings.
#
# For this to match the book, the bottom left split ("free <= 0.2") would be removed and there would be another split of the box on the bottom row, second from the right.
